# %%
# Python Programming Lab
## Experiment 02: Conditional Statements

Name: Hiteshri Soni
Roll No: 590029483
Subject: Python Programming

GitHub Repository Link: https://github.com/hiteshrisoni/PYTHON-EXPERIMENTS/tree/main

# %% [markdown]
# ## Question 1: Check whether the given number is divisible by 3 and 5 both

# %%
num = 15

if num % 3 == 0 and num % 5 == 0:
    print("Number is divisible by both 3 and 5")
else:
    print("Number is NOT divisible by both 3 and 5")
# Out:
# Number is divisible by both 3 and 5

# %% [markdown]
# ## Question 2: Check whether number is multiple of 5

# %%
num = 25

if num % 5 == 0:
    print("Number is a multiple of 5")
else:
    print("Number is NOT a multiple of 5")
# Out:
# Number is a multiple of 5

# %%
## Question 3: Find greatest among two numbers

# %%
a = 10
b = 20

if a > b:
    print("Greatest:", a)
elif b > a:
    print("Greatest:", b)
else:
    print("Numbers are equal")
# Out:
# Greatest: 20

# %% [markdown]
# ## Question 4: Find greatest among three numbers

# %%
a = 5
b = 8
c = 3

if a > b and a > c:
    print("Greatest:", a)
elif b > c:
    print("Greatest:", b)
else:
    print("Greatest:", c)
# Out:
# Greatest: 8

# %% [markdown]
# ## Question 5: Check quadratic roots

# %%
import math

a = 1
b = 4
c = 4

d = b*b - 4*a*c

if d > 0:
    print("Real and different roots")
elif d == 0:
    print("Real and equal roots")
else:
    print("Imaginary roots")
# Out:
# Real and equal roots

# %% [markdown]
# ## Question 6: Check Leap Year

# %%
year = 2024

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Leap Year

# %% [markdown]
# ## Question 7: Display Next Date

# %%
import datetime

day = 20
month = 9
year = 2005

current = datetime.date(year, month, day)
next_day = current + datetime.timedelta(days=1)

print("Next Date:", next_day)
# Out:
# Next Date: 2005-09-21

# %% [markdown]
# ## Question 8 & 9: Grade Sheet Program

# %%
name = "Rohit Sharma"
roll = "R17234512"
sem = 1

pds = 70
python_marks = 80
chemistry = 90
english = 60
physics = 50

total = pds + python_marks + chemistry + english + physics
percentage = total / 5
cgpa = percentage / 10

print("Name:", name)
print("Roll Number:", roll)
print("Semester:", sem)

print("Percentage:", percentage)
print("CGPA:", cgpa)

if cgpa <= 3.4:
    grade = "F"
elif cgpa <= 5:
    grade = "C+"
elif cgpa <= 6:
    grade = "B"
elif cgpa <= 7:
    grade = "B+"
elif cgpa <= 8:
    grade = "A"
elif cgpa <= 9:
    grade = "A+"
else:
    grade = "O (Outstanding)"

print("Grade:", grade)
# Out:
# Name: Rohit Sharma
# Roll Number: R17234512
# Semester: 1
# Percentage: 70.0
# CGPA: 7.0
# Grade: B+
